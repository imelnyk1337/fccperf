# %%
import matplotlib.pyplot as plt
import json
from tools.utilities import json2dict, plot_graph, divide_by_threads

# %%
data_Zbb_10 = json2dict("/home/ihor/PycharmProjects/fccperf/jsonfiles/perf_Zbb_10_ram.json", [1, 65, 3])

# %%
# time = data_Zbb_10["bench_time"]
divide_by_threads(data_Zbb_10["sys_time"], [1, 65, 3])
# Out:
# [5.91,
#  4.705,
#  2.807142857142857,
#  2.113,
#  2.4099999999999997,
#  2.165,
#  2.5163157894736843,
#  3.252272727272727,
#  3.0787999999999998,
#  2.619285714285714,
#  3.014516129032258,
#  3.373235294117647,
#  2.905135135135135,
#  2.699,
#  1.9216279069767441,
#  3.180869565217391,
#  2.596734693877551,
#  3.0234615384615386,
#  3.7690909090909095,
#  3.0444827586206897,
#  2.8968852459016396,
#  3.30125]

# %%
plot_graph(data_Zbb_10["real_time"], [300, 500], [1, 65, 3], "perf_Zbb_10", " Real time")

# %%
plot_graph(divide_by_threads(data_Zbb_10["real_time"], [1, 65, 3]), [0, 500], [1, 65, 3], "perf_Zbb_10", " Real time / N of threads")

# %%
plot_graph(data_Zbb_10["bench_time"], [90, 170], [1, 65, 3], "perf_Zbb_10", "Time")

# %%
plot_graph(divide_by_threads(data_Zbb_10["bench_time"], [1, 65, 3]), [0, 170], [1, 65, 3], "perf_Zbb_10", "Time / N of threads")

# %%
plot_graph(data_Zbb_10["user_time"], [450, 17500], [1, 65, 3], "perf_Zbb_10", "User time")

# %%
plot_graph(divide_by_threads(data_Zbb_10["user_time"], [1, 65, 3]), [250, 500], [1, 65, 3], "perf_Zbb_10", "User time / N of threads")

# %%
plot_graph(data_Zbb_10["sys_time"], [0, 220], [1, 65, 3], "perf_Zbb_10", "Sys time")

# %%
plot_graph(divide_by_threads(data_Zbb_10["sys_time"], [1, 65, 3]), [1, 6], [1, 65, 3], "perf_Zbb_10", "System time / N of threads")

# %%
plot_graph(data_Zbb_10["n_events"], [5500, 11000], [1, 65, 3], "perf_Zbb_10", "N of events")

# %%
plot_graph(divide_by_threads(data_Zbb_10["n_events"], [1, 65, 3]), [0, 6_500], [1, 65, 3], "perf_Zbb_10", "N of events / N threads / sec")
