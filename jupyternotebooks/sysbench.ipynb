# %%
import matplotlib.pyplot as plt
import json
from tools.utilities import json2dict, plot_graph, sysbench, divide_by_threads

# %%
data_sysbench = sysbench("/home/ihor/PycharmProjects/fccperf/jsonfiles/perf_sysbench_all.json")

# %%
def solve_linear(a: float, b: float):
    x = float()
    if a == 0.:
        if b == 0:
            print("There are many solutions")
            x = None
        elif b != 0:
            print("There is no solution")
            x = None
    else:
        if b == 0:
            x = 0
            print(f"The solution equals {x}")
        elif b != 0:
            x = -b/a
            print(f"The solution equals {x}")
    return x

res = solve_linear(2, 1)
# Out:
# The solution equals -0.5

# %%
print(data_sysbench["sys"], "\n", data_sysbench["nevents"])
# Out:
# [0.02, 0.03, 0.03, 0.02, 0.03, 0.02, 0.03, 0.04, 0.03, 0.02, 0.03, 0.02, 0.03, 0.01, 0.02, 0.01, 0.03, 0.02, 0.03, 0.02, 0.03, 0.02, 0.01, 0.02, 0.02, 0.01, 0.03, 0.01, 0.02, 0.04, 0.02, 0.03, 0.02, 0.03, 0.01, 0.02, 0.03, 0.05, 0.03, 0.03, 0.04, 0.04, 0.03, 0.03, 0.03, 0.04, 0.03, 0.05, 0.03, 0.06, 0.05, 0.04, 0.04, 0.07, 0.04, 0.06, 0.05, 0.06, 0.04, 0.06, 0.05, 0.08, 0.05, 0.06]
# ...

# %%
plot_graph(data_sysbench["time"], [0, 620], [1, 65, 1], "perf_sysbench", "Time")

# %%
plot_graph(data_sysbench["nevents"], [1_500, 60_000], [1, 65, 1], "perf_sysbench", "N of events")

# %%
plot_graph(data_sysbench["real"], [0, 620], [1, 65, 1], "perf_sysbench", "Real time")

# %%
plot_graph(data_sysbench["user"], [600, 1_200], [1, 65, 1], "perf_sysbench", "User time")

# %%
plot_graph(data_sysbench["sys"], [0.00, 0.09], [1, 65, 1], "perf_sysbench", "System time")

# %%
plot_graph(divide_by_threads(data_sysbench["sys"], [1, 65, 1]), [0.00, 0.021], [1, 65, 1], "perf_sysbench", "System time / N of threads")
