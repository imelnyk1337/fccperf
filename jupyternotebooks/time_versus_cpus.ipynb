facecolor='white')
ax = plt.axes()
ax.set_facecolor('white')
ax.set_alpha(0.1)
plt.grid()
plt.xlim([0, 65])
plt.ylim([5_000, 64_000])
plt.title("Dependence of running time on the number of CPUs", fontsize=14)
plt.plot(n_cpus, times, linewidth=2.5, color="red", label="Elapsed time of running")
plt.legend(fontsize=12)
plt.xlabel("Number of CPUs", fontsize=12)
plt.ylabel("Elapsed time (ms)", fontsize=18)
plt.show()
plt.savefig("time_performance")

# %%
n_cpus = [k for k in data.keys()]
times = [v[1] for k, v in data.items()]
plt.figure(figsize=(12, 8), facecolor='white')
ax = plt.axes()
ax.set_facecolor('white')
ax.set_alpha(0.1)
plt.grid()
plt.xlim([0, 65])
plt.ylim([5_000, 900_000])
plt.title("", fontsize=14)
plt.plot(n_cpus, times, linewidth=2.5, color="blue", label="Number of events processed per second ")
plt.legend(fontsize=12)
plt.xlabel("Number of CPUs", fontsize=12)
plt.ylabel("N of events / s", fontsize=18)
plt.show()
plt.savefig("performance_events")

# %%
data2 = {
    # 1: {
    #     "time": 0,
    #     "n_events": 0,
    #     "real": "0",
    #     "user": "0",
    #     "sys": "0"
    #     },
    2: {
        "time": 109.7028419971466,
        "n_events": 54693.2047590532,
        "real": "1m54.095s",
        "user": "3m33.562s",
        "sys": "0"
        },
    3: {
        "time": 101.22642207145691,
        "n_events": 59273.06208417137,
        "real": "1m45.777s",
        "user": "4m51.428s",
        "sys": "0m2.475s"
        },
    4: {
        "time": 103.9730052947998,
        "n_events": 57707.28645370885,
        "real": "1m48.375s",
        "user": "6m33.600s",
        "sys": "0m2.267s"
        },
    5: {
        "time": 103.8354389667511,
        "n_events": 57783.73992256387,
        "real": "1m48.260s",
        "user": "8m13.066s",
        "sys": "0m2.952s"
        },
    6: {
        "time": 102.81557846069336,
        "n_events": 58356.91526351539,
        "real": "1m47.242s",
        "user": "9m37.506s",
        "sys": "0m3.027s"
        },
    7: {
        "time": 103.24742531776428,
        "n_events": 58112.82926943523,
        "real": "1m47.708s",
        "user": "11m20.236s",
        "sys": "0m3.489s"
        },
    8: {
        "time": 107.5438904762268,
        "n_events": 55791.17487223818,
        "real": "1m51.952s",
        "user": "13m21.161s",
        "sys": "0m5.958s"
        },
    9: {
        "time": 109.66477632522583,
        "n_events": 54712.18928314943,
        "real": "1m54.160s",
        "user": "15m26.112s",
        "sys": "0m5.014s"
        },
    10: {
        "time": 108.05219268798828,
        "n_events": 55528.72043351875,
        "real": "1m52.517s",
        "user": "16m46.116s",
        "sys": "0m6.289s"
        },
    11: {
        "time": 109.2601478099823,
        "n_events": 54914.80764271695,
        "real": "1m53.740s",
        "user": "18m43.338s",
        "sys": "0m7.707s"
        },
    12: {
        "time": 109.3014407157898,
        "n_events": 54894.0614204844,
        "real": "1m53.807s",
        "user": "20m26.913s",
        "sys": "0m8.791s"
        },
    13: {
        "time": 109.7774007320404,
        "n_events": 54656.0581685261,
        "real": "1m54.280s",
        "user": "22m13.320s",
        "sys": "0m14.119s"
        },
    14: {
        "time": 109.08524131774902,
        "n_events": 55002.8576507696,
        "real": "1m54.123s",
        "user": "23m35.157s",
        "sys": "0m15.060s"
        },
    15: {
        "time": 120.65896582603455,
        "n_events": 49726.93043508071,
        "real": "2m5.204s",
        "user": "28m18.752s",
        "sys": "0m10.775s"
        },
    16: {
        "time": 111.90242457389832,
        "n_events": 53618.141187260066,
        "real": "1m56.421s",
        "user": "27m48.014s",
        "sys": "0m28.325s"
        },
    37: {
        "time": 124.91833901405334,
        "n_events": 48031.37831767839,
        "real": "2m9.501s",
        "user": "71m22.454s",
        "sys": "0m23.806s"
        },
    38: {
        "time": 124.61054229736328,
        "n_events": 48150.01916677284,
        "real": "2m9.139s",
        "user": "73m13.198s",
        "sys": "0m20.022s"
        },
    39: {
        "time": 122.64803147315979,
        "n_events": 48920.475346667394,
        "real": "2m7.131s",
        "user": "73m47.776s",
        "sys": "0m20.879s"
        },
    40: {
        "time": 121.19400548934937,
        "n_events": 49507.39911411943,
        "real": "2m6.808s",
        "user": "74m43.310s",
        "sys": "0m23.483s"
        },
    41: {
        "time": 119.52184581756592,
        "n_events": 50200.02794433242,
        "real": "2m4.551s",
        "user": "75m23.682s",
        "sys": "0m20.345s"
        },
    42: {
        "time": 121.07120656967163,
        "n_events": 49557.61299485555,
        "real": "2m5.858s",
        "user": "78m9.146s",
        "sys": "0m22.542s"
        },
    43: {
        "time": 118.60040402412415,
        "n_events": 50590.0468836477,
        "real": "2m4.599s",
        "user": "78m2.451s",
        "sys": "0m27.530s"
        },
    44: {
        "time": 118.27039551734924,
        "n_events": 50731.20770209864,
        "real": "2m3.632s",
        "user": "79m53.277s",
        "sys": "0m21.954s"
        },
    45: {
        "time": 116.32766103744507,
        "n_events": 51578.44614505437,
        "real": "2m0.984s",
        "user": "79m58.582s",
        "sys": "0m28.566s"
        },
    46: {
        "time": 115.20767736434937,
        "n_events": 52079.86253402831,
        "real": "1m59.768s",
        "user": "81m6.287s",
        "sys": "0m20.648s"
        },
    47: {
        "time": 114.21665740013123,
        "n_events": 52531.74218695973,
        "real": "1m58.881s",
        "user": "81m51.600s",
        "sys": "0m22.727s"
        },
    48: {
        "time": 114.12464714050293,
        "n_events": 52574.0946441936,
        "real": "1m58.714s",
        "user": "83m19.009s",
        "sys": "0m25.787s"
        },
    49: {
        "time": 114.93289518356323,
        "n_events": 52204.37534804284,
        "real": "1m59.469s",
        "user": "85m51.946s",
        "sys": "0m19.394s"
        },
    50: {
        "time": 110.60551881790161,
        "n_events": 54246.8410629515,
        "real": "1m55.171s",
        "user": "84m4.415s",
        "sys": "0m18.195s"
        },
    51: {
        "time": 109.91750073432922,
        "n_events": 54586.39397653345,
        "real": "1m54.594s",
        "user": "84m56.838s",
        "sys": "0m19.397s"
        },
    52: {
        "time": 110.06176018714905,
        "n_events": 54514.84684415003,
        "real": "1m54.632s",
        "user": "86m54.089s",
        "sys": "0m16.170s"
        },
    53: {
        "time": 109.01333665847778,
        "n_events": 55039.137264434794,
        "real": "1m53.524s",
        "user": "87m21.833s",
        "sys": "0m20.896s"
        },
    54: {
        "time": 107.89163732528687,
        "n_events": 55611.3536576552,
        "real": "1m52.549s",
        "user": "87m52.028s",
        "sys": "0m18.880s"
        },
    55: {
        "time": 107.42884707450867,
        "n_events": 55850.92052452748,
        "real": "1m52.000s",
        "user": "89m19.173s",
        "sys": "0m20.720s"
        },
    56: {
        "time": 107.22444748878479,
        "n_events": 55957.38789540113,
        "real": "1m51.785s",
        "user": "90m52.259s",
        "sys": "0m19.329s"
        },
    57: {
        "time": 107.21368408203125,
        "n_events": 55963.005575009294,
        "real": "1m51.917s",
        "user": "92m11.811s",
        "sys": "0m17.840s"
        },
    58: {
        "time": 105.90061378479004,
        "n_events": 56656.89541887952,
        "real": "1m50.467s",
        "user": "92m31.686s",
        "sys": "0m22.320s"
        },
    59: {
        "time": 104.06086778640747,
        "n_events": 57658.5620284797,
        "real": "1m48.724s",
        "user": "92m29.166s",
        "sys": "0m17.412s"
        },
    60: {
        "time": 104.69107556343079,
        "n_events": 57311.475383254496,
        "real": "1m49.318s",
        "user": "94m7.185s",
        "sys": "0m28.602s"
        },
    61: {
        "time": 102.38639521598816,
        "n_events": 58601.53575426464,
        "real": "1m46.981s",
        "user": "93m36.559s",
        "sys": "0m27.230s"
        },
    62: {
        "time": 102.17652821540833,
        "n_events": 58721.901250655275,
        "real": "1m46.825s",
        "user": "94m41.231s",
        "sys": "0m29.791s"
        },
    # 63: {
    #     "time": 0,
    #     "n_events": 0,
    #     "real": "0m0s",
    #     "user": "0m0s",
    #     "sys": "0m0s"
    #     },
    # 64: {
    #     "time": 0,
    #     "n_events": 0,
    #     "real": "0m0s",
    #     "user": "0m0s",
    #     "sys": "0m0s"
    #     }
}

# %%
n_cpus = [k for k in data2.keys()]
times = [v["time"]  * 1e3 for k, v in data2.items()]
plt.figure(figsize=(12, 8), facecolor='white')
ax = plt.axes()
ax.set_facecolor('white')
ax.set_alpha(0.1)
plt.grid()
plt.xlim([0, 65])
plt.ylim([5_000, 150_000])
plt.title("Dependence of running time on the number of CPUs", fontsize=14)
plt.plot(n_cpus, times, linewidth=2.5, color="red", label="Elapsed time of running")
plt.legend(fontsize=12)
plt.xlabel("Number of CPUs", fontsize=12)
plt.ylabel("Elapsed time (ms)", fontsize=18)
plt.show()
plt.savefig("time_performance")

# %%
def convert2sec(instr: str) -> float:
    minutes = instr.split("m")[0]
    sec = instr.split("m")[1].split("s")[0]
    return float(minutes) * 60.0 + float(sec)

convert2sec("43m19.322s")
# Out:
# 2599.322

# %%
n_cpus = [k for k in data2.keys()]
times = [v["real"] for k, v in data2.items()]
times_new = []
for time in times:
    time = convert2sec(time) * 1e3
    times_new.append(time)
print(times_new)
times_real = times_new
plt.figure(figsize=(12, 8), facecolor='white')
ax = plt.axes()
ax.set_facecolor('white')
ax.set_alpha(0.1)
plt.grid()
plt.xlim([0, 65])
plt.ylim([100_000, 150_000])
plt.title("Dependence of running time on the number of CPUs", fontsize=14)
plt.plot(n_cpus, times, linewidth=2.5, color="red", label="Real elapsed time of running")
plt.legend(fontsize=12)
plt.xlabel("Number of CPUs", fontsize=12)
plt.ylabel("Real time (ms)", fontsize=18)
plt.show()
plt.savefig("time_performance")
# Out:
# [114095.0, 105777.0, 108375.0, 108259.99999999999, 107241.99999999999, 107708.0, 111952.0, 114160.0, 112517.0, 113740.00000000001, 113807.0, 114280.0, 114122.99999999999, 125204.0, 116420.99999999999, 118868.0, 127871.0, 120245.0, 126272.0, 119878.99999999999, 120708.0, 122470.0, 124474.0, 126581.0, 126141.0, 126424.0, 128473.00000000001, 131569.0, 131234.0, 133150.0, 138552.0, 137389.0, 136324.0, 132510.0, 130615.99999999999, 129501.0, 129139.00000000001, 127131.0, 126808.0, 124551.0, 125858.0, 124599.0, 123632.0, 120984.0, 119768.0, 118881.0, 118714.0, 119469.0, 115170.99999999999, 114594.0, 114632.0, 113524.0, 112549.0, 112000.0, 111785.0, 111917.0, 110467.0, 108723.99999999999, 109318.0, 106981.0, 106825.0]

# %%
data3 = {
    # 1: {
    #     "time": 0,
    #     "n_events": 0,
    #     "real": "0",
    #     "user": "0",
    #     "sys": "0"
    #     },
    2: {
        "time": 1017.9953150749207,
        "n_events": 58742.90295294624,
        "real": "17m4.563s",
        "user": "33m41.108s",
        "sys": "0m14.272s"
        },
    3: {
        "time": 940.8594748973846,
        "n_events": 63558.90714340961,
        "real": "15m47.290s",
        "user": "46m39.789s",
        "sys": "0m14.888s"
        },
    4: {
        "time": 938.3138241767883,
        "n_events": 63731.342818554745,
        "real": "15m45.391s",
        "user": "62m1.014s",
        "sys": "0m14.951s"
        },
    5: {
        "time": 1081.962440252304,
        "n_events": 55269.940780989746,
        "real": "18m8.950s",
        "user": "89m22.505s",
        "sys": "0m19.356s"
        },
    6: {
        "time": 972.0065064430237,
        "n_events": 61522.22192301272,
        "real": "16m18.913s",
        "user": "96m20.593s",
        "sys": "0m14.281s"
        },
    7: {
        "time": 1013.466141462326,
        "n_events": 59005.42460522147,
        "real": "17m1.081s",
        "user": "116m58.504s",
        "sys": "0m18.592s"
        },
    8: {
        "time": 1032.7543189525604,
        "n_events": 57903.413137647614,
        "real": "17m20.469s",
        "user": "136m25.784s",
        "sys": "0m15.256s"
        },
    9: {
        "time": 0,
        "n_events": 0,
        "real": "",
        "user": "",
        "sys": ""
        },
    10: {
        "time": 0,
        "n_events": 0,
        "real": "",
        "user": "",
        "sys": ""
        },
    11: {
        "time": 0,
        "n_events": 0,
        "real": "",
        "user": "",
        "sys": ""
        },
    12: {
        "time": 0,
        "n_events": 0,
        "real": "",
        "user": "",
        "sys": ""
        },
    13: {
        "time": 0,
        "n_events": 0,
        "real": "",
        "user": "",
        "sys": ""
        },
    14: {
        "time": 0,
        "n_events": 0,
        "real": "",
        "user": "",
        "sys": ""
        },
    15: {
        "time": 0,
        "n_events": 0,
        "real": "",
        "user": "",
        "sys": ""
        },
    16: {
        "time": 0,
        "n_events": 0,
        "real": "",
        "user": "",
        "sys": ""
        },
    17: {
        "time": 0,
        "n_events": 0,
        "real": "",
         "user": "",
         "sys": ""
        },
    18: {
        "time": 0,
        "n_events": 0,
        "real": "",
        "user": "",
        "sys": ""
        },
    19: {
        "time": 0,
        "n_events": 0,
        "real": "",
        "user": "",
        "sys": ""
        },
    20: {
        "time": 0,
        "n_events": 0,
        "real": "",
        "user": "",
        "sys": ""
        },
    21: {
        "time": 0,
        "n_events": 0,
        "real": "",
        "user": "",
        "sys": ""
        },
    22: {
        "time": 0,
        "n_events": 0,
        "real": "",
        "user": "",
        "sys": ""
        },
    23: {
        "time": 0,
        "n_events": 0,
        "real": "",
        "user": "",
        "sys": ""
        },
    24: {
        "time": 0,
        "n_events": 0,
        "real": "",
        "user": "",
        "sys": ""
        },
    25: {
        "time": 0,
        "n_events": 0,
        "real": "",
        "user": "",
        "sys": ""
        },
    26: {
        "time": 0,
        "n_events": 0,
        "real": "",
        "user": "",
        "sys": ""
        },
    27: {
        "time": 0,
        "n_events": 0,
        "real": "",
        "user": "",
        "sys": ""
        },
    28: {
        "time": 0,
        "n_events": 0,
        "real": "",
        "user": "",
        "sys": ""
        },
    29: {
        "time": 0,
        "n_events": 0,
        "real": "",
        "user": "",
        "sys": ""
        },
    30: {
        "time": 0,
        "n_events": 0,
        "real": "",
        "user": "",
        "sys": ""
        },
    31: {
        "time": 0,
        "n_events": 0,
        "real": "",
        "user": "",
        "sys": ""
        },
    32: {
        "time": 0,
        "n_events": 0,
        "real": "",
        "user": "",
        "sys": ""
        },
    33: {
        "time": 0,
        "n_events": 0,
        "real": "",
        "user": "",
        "sys": ""
        },
    34: {
        "time": 0,
        "n_events": 0,
        "real": "",
        "user": "",
        "sys": ""
        },
    35: {
        "time": 0,
        "n_events": 0,
        "real": "",
        "user": "",
        "sys": ""
        },
    36: {
        "time": 0,
        "n_events": 0,
        "real": "",
        "user": "",
        "sys": ""
        },
    37: {
        "time": 0,
        "n_events": 0,
        "real": "",
        "user": "",
        "sys": ""
        },
    38: {
        "time": 0,
        "n_events": 0,
        "real": "",
        "user": "",
        "sys": ""
        },
    39: {
        "time": 0,
        "n_events": 0,
        "real": "",
        "user": "",
        "sys": ""
        },
    40: {
        "time": 0,
        "n_events": 0,
        "real": "",
        "user": "",
        "sys": ""
        },
    41: {
        "time": 0,
        "n_events": 0,
        "real": "",
        "user": "",
        "sys": ""
        },
    42: {
        "time": 0,
        "n_events": 0,
        "real": "",
        "user": "",
        "sys": ""
        },
    43: {
        "time": 0,
        "n_events": 0,
        "real": "",
        "user": "",
        "sys": ""
        },
    44: {
        "time": 0,
        "n_events": 0,
        "real": "",
        "user": "",
        "sys": ""
        },
    45: {
        "time": 0,
        "n_events": 0,
        "real": "",
        "user": "",
        "sys": ""
        },
    46: {
        "time": 0,
        "n_events": 0,
        "real": "",
        "user": "",
        "sys": ""
        },
    47: {
        "time": 0,
        "n_events": 0,
        "real": "",
        "user": "",
        "sys": ""
        },
    48: {
        "time": 0,
        "n_events": 0,
        "real": "",
        "user": "",
        "sys": ""
        },
    49: {
        "time": 0,
        "n_events": 0,
        "real": "",
        "user": "",
        "sys": ""
        },
    50: {
        "time": 0,
        "n_events": 0,
        "real": "",
        "user": "",
        "sys": ""
        },
    51: {
        "time": 0,
        "n_events": 0,
        "real": "",
        "user": "",
        "sys": ""
        },
    52: {
        "time": 0,
        "n_events": 0,
        "real": "",
        "user": "",
        "sys": ""
        },
    53: {
        "time": 0,
        "n_events": 0,
        "real": "",
        "user": "",
        "sys": ""
        },
    54: {
        "time": 0,
        "n_events": 0,
        "real": "",
        "user": "",
        "sys": ""
        },
    55: {
        "time": 0,
        "n_events": 0,
        "real": "",
        "user": "",
        "sys": ""
        },
    56: {
        "time": 0,
        "n_events": 0,
        "real": "",
        "user": "",
        "sys": ""
        },
    57: {
        "time": 0,
        "n_events": 0,
        "real": "",
        "user": "",
        "sys": ""
        },
    58: {
        "time": 0,
        "n_events": 0,
        "real": "",
        "user": "",
        "sys": ""
        },
    59: {
        "time": 0,
        "n_events": 0,
        "real": "",
        "user": "",
        "sys": ""
        },
    60: {
        "time": 0,
        "n_events": 0,
        "real": "",
        "user": "",
        "sys": ""
        },
    61: {
        "time": 0,
        "n_events": 0,
        "real": "",
        "user": "",
        "sys": ""
        },
    62: {
        "time": 0,
        "n_events": 0,
        "real": "",
        "user": "",
        "sys": ""
        },
    # 63: {
    #     "time": 0,
    #     "n_events": 0,
    #     "real": "0m0s",
    #     "user": "0m0s",
    #     "sys": "0m0s"
    #     },
    # 64: {
    #     "time": 0,
    #     "n_events": 0,
    #     "real": "0m0s",
    #     "user": "0m0s",
    #     "sys": "0m0s"
    #     }
}

# %%
timedata = """
"time": "155.68700456619263",
"nevents": "38538.86210167922",
"time": "156.00897645950317",
"nevents": "38459.32545783659",
"time": "156.0843756198883",
"nevents": "38440.74703935631",
"time": "154.4697048664093",
"nevents": "38842.56790151186",
"time": "156.69703459739685",
"nevents": "38290.45020166371",
"time": "156.08642554283142",
"nevents": "38440.242187194875",
"time": "155.83305549621582",
"nevents": "38502.74244379236",
"time": "154.0030791759491",
"nevents": "38960.25996431524",
"time": "154.43601369857788",
"nevents": "38851.04164699928",
"time": "155.37732124328613",
"nevents": "38615.674102177",
"time": "156.05686259269714",
"nevents": "38447.52419289491",
"time": "155.21531891822815",
#  '"time": "156.0843756198883",',
#  '"nevents": "38440.74703935631",',
#  '"time": "154.4697048664093",',
#  '"nevents": "38842.56790151186",',
#  '"time": "156.69703459739685",',
#  '"nevents": "38290.45020166371",',
#  '"time": "156.08642554283142",',
#  '"nevents": "38440.242187194875",',
#  '"time": "155.83305549621582",',
#  '"nevents": "38502.74244379236",',
#  '"time": "154.0030791759491",',
#  '"nevents": "38960.25996431524",',
#  '"time": "154.43601369857788",',
#  '"nevents": "38851.04164699928",',
#  '"time": "155.37732124328613",',
#  '"nevents": "38615.674102177",',
#  '"time": "156.05686259269714",',
#  '"nevents": "38447.52419289491",',
#  '"time": "155.21531891822815",',
#  '"nevents": "38655.978300447074",',
#  '"time": "154.96994304656982",',
#  '"nevents": "38717.185294421564",',
#  '"time": "154.47984290122986",',
# ...

# %%
for i in strip_s:
    print(i)

nn = len(strip_s)/2

time_list = list()
events_list = list()

for i in range(len(strip_s)):
    if "time" in strip_s[i]:
        time_list.append(strip_s[i])
    elif "nevents" in strip_s[i]:
        events_list.append(strip_s[i])
# Out:
# "time": "155.68700456619263",
# "nevents": "38538.86210167922",
# "time": "156.00897645950317",
# "nevents": "38459.32545783659",
# "time": "156.0843756198883",
# "nevents": "38440.74703935631",
# "time": "154.4697048664093",
# "nevents": "38842.56790151186",
# "time": "156.69703459739685",
# "nevents": "38290.45020166371",
# "time": "156.08642554283142",
# "nevents": "38440.242187194875",
# "time": "155.83305549621582",
# "nevents": "38502.74244379236",
# "time": "154.0030791759491",
# "nevents": "38960.25996431524",
# "time": "154.43601369857788",
# "nevents": "38851.04164699928",
# "time": "155.37732124328613",
# "nevents": "38615.674102177",
# "time": "156.05686259269714",
# "nevents": "38447.52419289491",
# "time": "155.21531891822815",
# "nevents": "38655.978300447074",
# "time": "154.96994304656982",
# "nevents": "38717.185294421564",
# "time": "154.47984290122986",
# "nevents": "38840.0187837855",
# "time": "155.4699935913086",
# "nevents": "38592.656122264256",
# ...

# %%
times = list()
nevents = list()

for t, nev in zip(time_list, events_list):
    times.append(float(t.split(":")[1].split("\"")[1]))
    nevents.append(float(nev.split(":")[1].split("\"")[1]))

# %%
n_cpus = [k for k in range(1, 64)]
plt.figure(figsize=(12, 8), facecolor='white')
ax = plt.axes()
ax.set_facecolor('white')
ax.set_alpha(0.1)
plt.grid()
plt.xlim([0, 65])
plt.ylim([150, 160])
plt.title("Dependence of running time on the number of CPUs", fontsize=14)
plt.plot(n_cpus, times, linewidth=2.5, color="red", label="Elapsed time of running")
plt.legend(fontsize=12)
plt.xlabel("Number of CPUs", fontsize=12)
plt.ylabel("Elapsed time (ms)", fontsize=18)
plt.show()
plt.savefig("time_performance")

# %%
times = [v[1] for k, v in data.items()]
plt.figure(figsize=(12, 8), facecolor='white')
ax = plt.axes()
ax.set_facecolor('white')
ax.set_alpha(0.1)
plt.grid()
plt.xlim([0, 65])
plt.ylim([38_000, 39_250])
plt.title("", fontsize=14)
plt.plot(n_cpus, nevents, linewidth=2.5, color="blue", label="Number of events processed per second ")
plt.legend(fontsize=12)
plt.xlabel("Number of CPUs", fontsize=12)
plt.ylabel("N of events / s", fontsize=18)
plt.show()
plt.savefig("performance_events")
