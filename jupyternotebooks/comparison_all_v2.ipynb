# %% [markdown]
# ### Comparison of C++, FCCAnalysis and Python standalone streering scripts' time output (each version was run from Random Access Memory)

# %%
import matplotlib.pyplot as plt
from tools.utilities  import json2dict, json2dict_cpp, json2dict_py, plot_graph, divide_by_threads, json2dict_cpp_updated

# %%
data_fcc_wcr = json2dict("/home/ihor/PycharmProjects/fccperf/json2/perf_fccanalysis.json", [1, 65, 3])
data_fcc_wocr = json2dict("/home/ihor/PycharmProjects/fccperf/json2/perf_fccanalysis_wocr.json", [1, 65, 3])
data_py_wcr = json2dict_py("/home/ihor/PycharmProjects/fccperf/json2/perf_py.json", [1, 65, 3])
data_py_wocr = json2dict_py("/home/ihor/PycharmProjects/fccperf/json2/perf_py_wocr.json", [1, 65, 3])
data_cpp_wcr = json2dict_cpp("/home/ihor/PycharmProjects/fccperf/json2/perf_cpp.json", [1, 65, 3])
data_cpp_wocr = json2dict_cpp("/home/ihor/PycharmProjects/fccperf/json2/perf_cpp_wocr.json", [1, 65, 3])

# %%
real_fcc_wcr = data_fcc_wcr["real_time"]
real_fcc_wocr = data_fcc_wocr["real_time"]
real_py_wcr = data_py_wcr["real_time"]
real_py_wocr = data_py_wocr["real_time"]
real_cpp_wcr = data_cpp_wcr["real_time"]
real_cpp_wocr = data_cpp_wocr["real_time"]
n_threads = [i for i in range(1, 65, 3)]
# n_threads_1 = [i for i in range(1, 65, 1)]

ratio_py = [abs(py - fcc)/fcc for py, fcc in zip(real_py_wcr, real_fcc_wcr)]
ratio_cpp = [abs(cpp - fcc)/fcc for cpp, fcc in zip(real_cpp_wcr, real_fcc_wcr)]

# %%
ratio_cpp
# Out:
# [0.44674190988448986,
#  0.4497198466529048,
#  0.35238305383936447,
#  0.28853984874927263,
#  0.17996108949416345,
#  0.1676602086438152,
#  0.1976023150062008,
#  0.17462482946793997,
#  0.1366016182770108,
#  0.10292682926829265,
#  0.11369509043927645,
#  0.09019402202412159,
#  0.07847186370676301,
#  0.08989952406134316,
#  0.0870499731327244,
#  0.07502679528402993,
#  0.11357490535424562,
#  0.10204081632653053,
#  0.11683483802442926,
#  0.12069878242456332,
#  0.11271367521367519,
#  0.0848237097598365]

# %%
plt.figure(figsize=(16, 10), facecolor='white')
ax = plt.axes()
ax.set_facecolor('white')
ax.set_alpha(0.1)
plt.plot(n_threads, ratio_py, color='b', label='Real Time Ratio Python', linewidth=3)
plt.vlines(x = 32, ymin = 75, ymax = 250, color = 'r', label = '32 threads', linestyles="dashed")
plt.xlabel("Number of threads")
plt.ylabel("Real time Ratio")
plt.title("")
plt.legend()
plt.xlim((0, 65))
plt.ylim((0.0, 0.6))
plt.grid()
plt.show()

# %%
plt.figure(figsize=(16, 10), facecolor='white')
ax = plt.axes()
ax.set_facecolor('white')
ax.set_alpha(0.1)
plt.plot(n_threads, real_py_wcr, color='b', label='Real Time Py wcr', linewidth=3)
plt.plot(n_threads, real_fcc_wcr, color='g', label='Real Time FCC wcr', linewidth=3)
plt.vlines(x = 32, ymin = 75, ymax = 250, color = 'r', label = '32 threads', linestyles="dashed")
plt.xlabel("Number of threads")
plt.ylabel("Real time")
plt.title("")
plt.legend()
plt.xlim((0, 65))
plt.ylim((0, 355))
plt.grid()
plt.show()

# %%
plt.figure(figsize=(16, 10), facecolor='white')
ax = plt.axes()
ax.set_facecolor('white')
ax.set_alpha(0.1)
plt.plot(n_threads, real_fcc_wcr, color='b', label='Real Time FCC wcr', linewidth=3)
plt.plot(n_threads, real_fcc_wocr, color='g', label='Real Time FCC wocr', linewidth=3)
plt.vlines(x = 32, ymin = 75, ymax = 250, color = 'r', label = '32 threads', linestyles="dashed")
plt.xlabel("Number of threads")
plt.ylabel("Real time")
plt.title("")
plt.legend()
plt.xlim((0, 65))
plt.ylim((0, 250))
plt.grid()
plt.show()

# %%
plt.figure(figsize=(16, 10), facecolor='white')
ax = plt.axes()
ax.set_facecolor('white')
ax.set_alpha(0.1)
plt.plot(n_threads, real_cpp_wcr, color='b', label='Real Time C++ wcr', linewidth=3)
plt.plot(n_threads, real_cpp_wocr, color='g', label='Real Time C++ wocr', linewidth=3)
plt.vlines(x = 32, ymin = 75, ymax = 250, color = 'r', label = '32 threads', linestyles="dashed")
plt.xlabel("Number of threads")
plt.ylabel("Real time")
plt.title("")
plt.legend()
plt.xlim((0, 65))
plt.ylim((0, 350))
plt.grid()
plt.show()

# %%
plt.figure(figsize=(16, 10), facecolor='white')
ax = plt.axes()
ax.set_facecolor('white')
ax.set_alpha(0.1)
plt.plot(n_threads, real_py_wcr, color='b', label='Real Time Python wcr', linewidth=3)
plt.plot(n_threads, real_py_wocr, color='g', label='Real Time Python wocr', linewidth=3)
plt.vlines(x = 32, ymin = 75, ymax = 250, color = 'r', label = '32 threads', linestyles="dashed")
plt.xlabel("Number of threads")
plt.ylabel("Real time")
plt.title("")
plt.legend()
plt.xlim((0, 65))
plt.ylim((0, 380))
plt.grid()
plt.show()

# %%
plt.figure(figsize=(16, 10), facecolor='white')
ax = plt.axes()
ax.set_facecolor('white')
ax.set_alpha(0.1)
plt.plot(n_threads, real_fcc_wcr, color='b', label='Real Time FCC wcr', linewidth=3)
plt.plot(n_threads, real_fcc_wocr, color='g', label='Real Time FCC wocr', linewidth=3)
plt.vlines(x = 32, ymin = 75, ymax = 250, color = 'r', label = '32 threads', linestyles="dashed")
plt.xlabel("Number of threads")
plt.ylabel("Real time")
plt.title("")
plt.legend()
plt.xlim((0, 65))
plt.ylim((0, 250))
plt.grid()
plt.show()

# %%
plt.figure(figsize=(16, 10), facecolor='white')
ax = plt.axes()
ax.set_facecolor('white')
ax.set_alpha(0.1)
plt.plot(n_threads, real_py_wcr, color='b', label='Real Time Py wcr', linewidth=3)
plt.plot(n_threads, real_cpp_wcr, color='g', label='Real Time C++ wcr', linewidth=3)
plt.vlines(x = 32, ymin = 75, ymax = 250, color = 'r', label = '32 threads', linestyles="dashed")
plt.xlabel("Number of threads")
plt.ylabel("Real time")
plt.title("")
plt.legend()
plt.xlim((0, 65))
plt.ylim((0, 380))
plt.grid()
plt.show()

# %%
plt.figure(figsize=(16, 10), facecolor='white')
ax = plt.axes()
ax.set_facecolor('white')
ax.set_alpha(0.1)
plt.plot(n_threads, real_cpp_wcr, color='b', label='Real Time C++ wcr', linewidth=3)
plt.plot(n_threads, real_fcc_wcr, color='g', label='Real Time FCC wcr', linewidth=3)
plt.vlines(x = 32, ymin = 75, ymax = 250, color = 'r', label = '32 threads', linestyles="dashed")
plt.xlabel("Number of threads")
plt.ylabel("Real time")
plt.title("")
plt.legend()
plt.xlim((0, 65))
plt.ylim((0, 380))
plt.grid()
plt.show()

# %%
plt.figure(figsize=(16, 10), facecolor='white')
ax = plt.axes()
ax.set_facecolor('white')
ax.set_alpha(0.1)
plt.plot(n_threads, real_cpp_wcr, color='b', label='Real Time C++ wcr', linewidth=3)
plt.plot(n_threads, real_fcc_wcr, color='g', label='Real Time FCC wcr', linewidth=3)
plt.plot(n_threads, real_py_wcr, color='y', label='Real Time Py wcr', linewidth=3)
plt.vlines(x = 32, ymin = 75, ymax = 250, color = 'r', label = '32 threads', linestyles="dashed")
plt.xlabel("Number of threads")
plt.ylabel("Real time")
plt.title("")
plt.legend()
plt.xlim((0, 65))
plt.ylim((0, 380))
plt.grid()
plt.show()

# %%
plt.figure(figsize=(16, 10), facecolor='white')
ax = plt.axes()
ax.set_facecolor('white')
ax.set_alpha(0.1)
plt.plot(n_threads, ratio_cpp, color='b', label='Real Time Ratio C++', linewidth=3)
plt.vlines(x = 32, ymin = 75, ymax = 250, color = 'r', label = '32 threads', linestyles="dashed")
plt.xlabel("Number of threads")
plt.ylabel("Real time Ratio")
plt.title("")
plt.legend()
plt.xlim((0, 65))
plt.ylim((0.0, 0.5))
plt.grid()
plt.show()

# %%
def compute_nevents(total: int, datatime: list) -> list:
    result = list()
    for time in datatime:
        result.append(total/time)
    return result

# %%
total_events = 10000000
nevents_p =  compute_nevents(total_events, data_ZH_100_ram_p["real_time"])
nevents_c =  compute_nevents(total_events, data_ZH_100_ram_c["real_time"])
nevents_c_wo_cache =  compute_nevents(total_events, data_ZH_100_ram_c_wo_cache["real_time"])
nevents_p_bench = data_ZH_100_ram_p["n_events"]

# %%
plt.figure(figsize=(16, 10), facecolor='white')
ax = plt.axes()
ax.set_facecolor('white')
ax.set_alpha(0.1)
plt.plot(n_threads, nevents_p, color = 'b', label = 'Number of events (Python) calculated', linewidth = 3)
plt.plot(n_threads, nevents_p_bench, color = 'y', label = 'Number of events (Python) from bench', linewidth = 3)
plt.plot(n_threads, nevents_c, color = 'g', label = 'Number of events (C++) calculated', linewidth = 3)
# plt.plot(n_threads, nevents_c_wo_cache, color = 'pink', label = 'Number of events (C++) calculated wo cache', linewidth = 3)
plt.vlines(x = 32, ymin = 40_000, ymax = 100_000, color = 'r', label = '32 threads', linestyles = "dashed")
plt.xlabel("Number of threads")
plt.ylabel("Number of events")
plt.title("Comparison of C++ and Python versions")
plt.legend()
plt.xlim((0, 65))
plt.ylim((20_000, 120_000))
plt.grid()
plt.show()
