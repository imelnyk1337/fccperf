# %%
import matplotlib.pyplot as plt
import json
from tools.utilities  import json2dict, plot_graph, divide_by_threads

# %%
data_cpp = json2dict("/home/ihor/PycharmProjects/fccperf/jsonfiles/perf_cpp_v3.json", [1, 65, 1])

# %%
data_cpp["sys_time"]
# Out:
# [1.08,
#  1.32,
#  2.58,
#  3.25,
#  3.72,
#  3.9,
#  3.45,
#  9.23,
#  3.29,
#  5.1,
#  5.53,
#  8.19,
#  3.46,
#  2.93,
#  8.42,
#  12.78,
#  13.7,
#  12.61,
#  10.07,
#  14.89,
#  20.44,
#  21.09,
#  25.77,
#  17.92,
#  19.64,
#  24.17,
#  24.93,
#  25.45,
#  27.99,
#  19.18,
#  25.54,
#  27.08,
#  37.81,
#  25.71,
#  28.03,
#  31.56,
#  27.21,
#  36.61,
#  27.11,
#  21.5,
#  39.28,
#  28.24,
#  27.73,
#  26.25,
#  42.58,
#  31.43,
#  32.11,
#  34.93,
#  37.71,
#  25.91,
#  50.86,
#  33.98,
#  30.43,
#  36.67,
#  53.44,
#  46.83,
#  33.76,
#  51.76,
#  44.7,
#  36.76,
#  55.53,
#  34.23,
#  51.03,
#  42.56]

# %%
plot_graph(data_cpp["real_time"], [55, 75], [1, 65, 1], "perf_cpp", "Real time")

# %%
plot_graph(data_cpp["user_time"], [0, 3_000], [1, 65, 1], "perf_cpp", "User time")

# %%
plot_graph(data_cpp["sys_time"], [0, 65], [1, 65, 1], "perf_cpp", "System time")

# %%
data_cpp = json2dict("/home/ihor/PycharmProjects/fccperf/jsonfiles/perf_cpp_v2.json", [1, 65, 1])

# %%
data_cpp["sys_time"]
# Out:
# [1.75,
#  2.21,
#  3.09,
#  4.94,
#  7.71,
#  4.01,
#  4.12,
#  6.62,
#  5.97,
#  7.02,
#  8.93,
#  10.11,
#  7.03,
#  7.93,
#  8.68,
#  11.78,
#  14.41,
#  16.68,
#  9.8,
#  12.5,
#  26.55,
#  24.13,
#  15.0,
#  16.36,
#  18.52,
#  33.5,
#  30.45,
#  25.09,
#  27.72,
#  26.3,
#  24.38,
#  25.36,
#  35.83,
#  44.78,
#  36.51,
#  28.69,
#  42.95,
#  31.22,
#  31.03,
#  25.15,
#  37.79,
#  35.08,
#  32.38,
#  34.29,
#  24.43,
#  30.34,
#  40.2,
#  41.3,
#  33.1,
#  33.99,
#  30.39,
#  44.62,
#  37.72,
#  39.58,
#  34.11,
#  36.79,
#  45.31,
#  32.33,
#  29.42,
#  44.54,
#  26.38,
#  40.6,
#  39.98,
#  45.75]

# %%
plot_graph(data_cpp["real_time"], [50, 80], [1, 65, 1], "perf_cpp", "Real time")

# %%
plot_graph(data_cpp["user_time"], [0, 3_000], [1, 65, 1], "perf_cpp", "User time")

# %%
plot_graph(data_cpp["sys_time"], [1.5, 50], [1, 65, 1], "perf_cpp", "System time")
