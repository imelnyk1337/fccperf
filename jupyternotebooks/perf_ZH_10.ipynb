# %%
import matplotlib.pyplot as plt
import json
from utilities import json2dict, plot_graph

# %%
data_ZH_10 = json2dict("/home/ihor/PycharmProjects/fccperf/jsonfiles/perf_ZH_10.json")

# %%
data_ZH_10["sys_time"]
# Out:
# [0.79,
#  1.13,
#  1.97,
#  1.71,
#  1.92,
#  2.3,
#  2.21,
#  1.73,
#  1.95,
#  1.94,
#  2.74,
#  3.56,
#  3.65,
#  3.61,
#  4.41,
#  3.92,
#  4.38,
#  4.55,
#  4.89,
#  3.85,
#  5.28,
#  6.31,
#  4.43,
#  5.32,
#  5.34,
#  5.43,
#  5.69,
#  5.56,
#  6.18,
#  6.4,
#  6.72,
#  6.96,
#  6.65,
#  6.69,
#  7.46,
#  7.93,
#  8.17,
#  8.4,
#  7.92,
#  8.75,
#  8.67,
#  9.51,
#  9.16,
#  9.19,
#  9.64,
#  9.53,
#  8.99,
#  9.0,
#  9.68,
#  9.53,
#  9.44,
#  9.31,
#  10.44,
#  10.98,
#  10.83,
#  10.12,
#  11.23,
#  11.62,
#  10.63,
#  12.05,
#  10.76,
#  12.4,
#  13.66,
#  11.94]

# %%
plot_graph(data_ZH_10["bench_time"], [20, 34.5],"perf_ZH_10", "Time")

# %%
plot_graph(data_ZH_10["n_events"], [20_000, 50_000],"perf_ZH_10", "N events")

# %%
plot_graph(data_ZH_10["real_time"], [20, 37.5],"perf_ZH_10", "Real time")

# %%
plot_graph(data_ZH_10["user_time"], [20, 1_000],"perf_ZH_10", "User time")

# %%
plot_graph(data_ZH_10["sys_time"], [0, 16],"perf_ZH_10", "System time")
