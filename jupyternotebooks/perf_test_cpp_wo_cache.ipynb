# %%
import matplotlib.pyplot as plt
import json
from tools.utilities  import json2dict_cpp, plot_graph, divide_by_threads, compute_nevents

# %%
data_cpp = json2dict_cpp("/home/ihor/PycharmProjects/fccperf/jsonfiles/perf_cpp_without_cache.json", [1, 65, 1])

# %%
data_cpp["sys_time"]
# Out:
# [4.27,
#  4.96,
#  5.16,
#  5.16,
#  5.51,
#  5.02,
#  5.07,
#  6.65,
#  6.7,
#  6.27,
#  13.73,
#  15.35,
#  19.59,
#  21.18,
#  24.43,
#  37.76,
#  38.54,
#  45.22,
#  40.18,
#  44.77,
#  38.98,
#  46.47,
#  38.46,
#  52.23,
#  74.92,
#  64.92,
#  39.36,
#  71.37,
#  70.76,
#  100.69,
#  80.66,
#  77.99,
#  45.64,
#  95.68,
#  77.52,
#  87.67,
#  86.08,
#  83.75,
#  105.42,
#  119.11,
#  101.75,
#  70.46,
#  46.12,
#  105.06,
#  136.27,
#  62.7,
#  144.14,
#  91.15,
#  94.37,
#  73.74,
#  91.07,
#  117.58,
#  98.43,
#  69.16,
#  84.93,
#  94.36,
#  123.59,
#  140.92,
#  79.08,
#  71.76,
#  96.57,
#  92.8,
#  87.69,
#  102.97]

# %%
plot_graph(data_cpp["real_time"], [70.5, 350], [1, 65, 1], "perf_cpp", "Real time")

# %%
nevents = compute_nevents(10000000, data_cpp["real_time"])
plot_graph(nevents, [20_000, 120_000], [1, 65, 1], "perf_cpp", "Number of events")

# %%
plot_graph(data_cpp["user_time"], [5, 5000], [1, 65, 1], "perf_cpp", "User time")

# %%
plot_graph(data_cpp["sys_time"], [0.5, 160], [1, 65, 1], "perf_cpp", "System time")
