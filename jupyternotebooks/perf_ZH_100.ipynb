# %%
import matplotlib.pyplot as plt
import json
from utilities import json2dict, plot_graph

# %%
data_ZH_100 = json2dict("/home/ihor/PycharmProjects/fccperf/jsonfiles/perf_ZH_100.json")

# %%
data_ZH_100["bench_time"]
# Out:
# [282.84791588783264,
#  193.88664650917053,
#  162.31849312782288,
#  163.9690399169922,
#  162.7340714931488,
#  157.59408330917358,
#  170.4446895122528,
#  157.19763946533203,
#  182.05158829689026,
#  162.25347137451172,
#  164.38243293762207,
#  180.71728777885437,
#  172.71048259735107,
#  190.54336500167847,
#  170.89526391029358,
#  178.10562920570374,
#  180.62595510482788,
#  195.29511499404907,
#  181.83727836608887,
#  183.68432211875916,
#  183.13902854919434,
#  177.09868669509888,
#  192.27594709396362,
#  204.07128190994263,
#  191.86882138252258,
#  190.85240769386292,
#  191.54628944396973,
#  205.2813413143158,
#  200.76367783546448,
#  204.03283882141113,
#  209.41549801826477,
#  208.35513544082642,
#  207.09301090240479,
#  205.86600518226624,
#  202.32666325569153,
#  202.48976731300354,
#  199.32376885414124,
#  197.0930643081665,
#  195.74964332580566,
#  191.67848324775696,
#  190.11070275306702,
#  191.72751641273499,
#  188.7388195991516,
# ...

# %%
plot_graph(data_ZH_100["bench_time"], [150, 300],"perf_ZH_100", "Time")

# %%
plot_graph(data_ZH_100["n_events"], [34_000, 70_000],"perf_ZH_100", "N events")

# %%
plot_graph(data_ZH_100["real_time"], [150, 300],"perf_ZH_100", "Real time")

# %%
plot_graph(data_ZH_100["user_time"], [0, 10_000],"perf_ZH_100", "User time")

# %%
plot_graph(data_ZH_100["sys_time"], [0, 100],"perf_ZH_100", "System time")
