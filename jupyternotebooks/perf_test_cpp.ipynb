# %%
import matplotlib.pyplot as plt
import json
from tools.utilities  import json2dict, plot_graph, divide_by_threads

# %%
data_cpp = json2dict("/home/ihor/PycharmProjects/fccperf/jsonfiles/perf_cpp.json", [1, 65, 1])

# %%
data_cpp["sys_time"]
# Out:
# [0.66,
#  0.61,
#  0.6,
#  0.61,
#  0.62,
#  0.71,
#  0.72,
#  0.74,
#  0.75,
#  0.83,
#  0.8,
#  0.95,
#  0.94,
#  0.97,
#  1.02,
#  1.01,
#  1.12,
#  1.21,
#  1.17,
#  1.18,
#  1.33,
#  1.26,
#  1.45,
#  1.35,
#  1.37,
#  1.47,
#  1.42,
#  1.53,
#  1.66,
#  1.62,
#  1.66,
#  1.78,
#  1.77,
#  2.0,
#  2.05,
#  1.99,
#  1.88,
#  1.94,
#  1.97,
#  1.95,
#  1.96,
#  2.0,
#  1.98,
#  1.97,
#  2.07,
#  1.86,
#  2.12,
#  1.94,
#  2.09,
#  1.98,
#  1.88,
#  1.93,
#  2.17,
#  2.24,
#  2.09,
#  1.98,
#  2.06,
#  2.09,
#  2.15,
#  2.49,
#  2.15,
#  2.21,
#  2.01,
#  2.04]

# %%
plot_graph(data_cpp["real_time"], [5.5, 7], [1, 65, 1], "perf_cpp", "Real time")

# %%
plot_graph(data_cpp["user_time"], [5, 35], [1, 65, 1], "perf_cpp", "User time")

# %%
plot_graph(data_cpp["sys_time"], [0.5, 3], [1, 65, 1], "perf_cpp", "System time")
